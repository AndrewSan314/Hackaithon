# %% [markdown]
# # Hackaithon vLLM ckpt12 Runner
#
# Notebook mỏng này gọi package Python đã refactor. Logic inference nằm trong `hackaithon_vllm.run` và chỉ chạy checkpoint `ckpt12_internal_rag`.

# %%
import os, sys
from pathlib import Path

SRC = Path('/app/src') if Path('/app/src').exists() else Path.cwd()
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

os.environ.setdefault('CHECKPOINT_TO_RUN', 'ckpt12_internal_rag')
os.environ.setdefault('PRED_PATH', '/kaggle/working/pred.csv')

from hackaithon_vllm.run import main
main([])
